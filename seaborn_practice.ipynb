# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline
df = sns.load_dataset('tips')
df.head()
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
df['total_bill'].hist()
# Out:
# <Axes: >
